# %% [markdown]
# # Kokoro 82M Voice Notes - Colab Launcher
# Run these cells top-to-bottom on a **T4 GPU** runtime.

# %% [markdown]
# ## 1) Clone your GitHub repo
# Replace `YOUR_USERNAME` if needed.

# %%
REPO_URL = "https://github.com/vikramnairoffice/kokoro-voice-notes-colab.git"
# !git clone $REPO_URL
# %cd kokoro-voice-notes-colab

# %% [markdown]
# ## 2) Install system and Python dependencies

# %%
# !apt-get update -y
# !apt-get install -y espeak-ng
# !pip install -r requirements.txt

# %% [markdown]
# ## 3) Start Gradio app
# The app will mount Google Drive when running in Colab.

# %%
# !python app.py
