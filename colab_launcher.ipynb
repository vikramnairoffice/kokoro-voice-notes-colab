# %% [markdown]
# # Kokoro 82M Voice Notes - Colab Launcher
# Run these cells top-to-bottom on a **T4 GPU** runtime.

# %% [markdown]
# ## 1) Install with pip (no git clone)
# This installs Python dependencies and downloads `app.py` directly from GitHub.

# %%
REPO_RAW = "https://raw.githubusercontent.com/vikramnairoffice/kokoro-voice-notes-colab/master"
# !pip install -r $REPO_RAW/requirements.txt
# !wget -q -O app.py $REPO_RAW/app.py
# !python - <<'PY'
from pathlib import Path
print("app.py downloaded:", Path("app.py").exists())
PY

# %% [markdown]
# ## 2) Install system dependency

# %%
# !apt-get update -y
# !apt-get install -y espeak-ng

# %% [markdown]
# ## 3) Start Gradio app
# The app will mount Google Drive when running in Colab.

# %%
# !python app.py
